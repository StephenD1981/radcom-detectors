# %%
import pandas as pd
pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("./cell_coverage.csv", nrows = 5, engine = "c")

# %%
df.head()
# Out:
#           grid_cell     grid cell_name      cilac  avg_rsrp  avg_rsrq  \
# 0  gc1zpnu_28167169  gc1zpnu   CK002H1  328167169    -107.0     -15.0
# 1  gc1zq8b_28167169  gc1zq8b   CK002H1  328167169    -116.0     -18.0
# 2  gc1zq8m_28167169  gc1zq8m   CK002H1  328167169    -116.0     -16.0
# 3  gc1zq9q_28167169  gc1zq9q   CK002H1  328167169    -116.0     -15.0
# 4  gc1zq9u_28167169  gc1zq9u   CK002H1  328167169    -117.0     -12.5
#
#     avg_sinr  event_count  grid_event_count  cell_event_count  avg_rsrp_grid  \
# 0  13.013048            1              1630              3633    -104.778661
# 1  10.011677            1               730              3633    -106.452096
# 2  12.012482            1               175              3633    -103.328581
# 3  13.013048            1               734              3633    -104.517364
# 4  15.515187            1               179              3633    -105.255364
#
#    avg_rsrq_grid  avg_sinr_grid  avg_rsrp_cell  avg_rsrq_cell  avg_sinr_cell  \
# ...
