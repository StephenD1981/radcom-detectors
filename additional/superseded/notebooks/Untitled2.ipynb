# %%
import geopandas as gpd

# %%
gdf = gpd.read_file("./cell_coverage.csv")
gdf.head()
# Out:
#           grid_cell     grid cell_name      cilac avg_rsrp avg_rsrq  \
# 0  gc1zpnu_28167169  gc1zpnu   CK002H1  328167169   -107.0    -15.0
# 1  gc1zq8b_28167169  gc1zq8b   CK002H1  328167169   -116.0    -18.0
# 2  gc1zq8m_28167169  gc1zq8m   CK002H1  328167169   -116.0    -16.0
# 3  gc1zq9q_28167169  gc1zq9q   CK002H1  328167169   -116.0    -15.0
# 4  gc1zq9u_28167169  gc1zq9u   CK002H1  328167169   -117.0    -12.5
#
#              avg_sinr event_count grid_event_count cell_event_count  ...  \
# 0  13.013047545071291           1             1630             3633  ...
# 1  10.011676795601396           1              730             3633  ...
# 2   12.01248230169876           1              175             3633  ...
# 3  13.013047545071291           1              734             3633  ...
# 4  15.515187140110012           1              179             3633  ...
#
#         max_dist_2_dt perc_dist_reduct_2_dt      max_dist_1_ut  \
# ...

# %%
gdf.shape
# Out:
# (1950805, 55)

# %%
gdf[gdf['avg_rsrp'].astype(float) >= -115].shape
# Out:
# (1689825, 55)

# %%
gdf[gdf['avg_rsrp'].astype(float) <= -115].shape[0]/gdf.shape[0]
# Out:
# 0.16349865824621118
