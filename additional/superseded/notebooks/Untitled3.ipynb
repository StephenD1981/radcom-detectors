# %%
import pandas as pd

# %%
df = pd.read_csv("./impact_matrix.csv")
df.shape
# Out:
# (1538461, 54)

# %%
def left(s, amount):
    return s[:amount]

# %%
df_filtered = df[
    (df['cell_name'].str[:2] == "CK") &
    (df['cell_impact_name'].str[:2] == "CK") &
    (df['cell_Tech'].str[:2] == "LTE") &
    (df['cell_impact_Tech'].str[:2] == "LTE")
]
df_filtered.shape
# Out:
# (0, 54)

# %%
df.cell_Tech
# Out:
# 0           LTE
# 1           LTE
# 2           LTE
# 3          UMTS
# 4           LTE
#            ...
# 1538456     GSM
# 1538457    UMTS
# 1538458     LTE
# 1538459    UMTS
# 1538460     LTE
# Name: cell_Tech, Length: 1538461, dtype: object
